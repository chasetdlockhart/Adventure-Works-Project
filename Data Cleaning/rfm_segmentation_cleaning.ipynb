# %% [markdown]
# Cleaning rfm segmentation. All data types are what they should be and no null values to take care of. Ready for Tableau.

# %%
import pandas as pd

rfm_segmentation = pd.read_csv(r"C:\Users\chase\OneDrive\Desktop\Adventure Works Project\Raw csvs\rfm_segmentation.csv")

rfm_segmentation.info()
print(rfm_segmentation.head())
rfm_segmentation.tail()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 19119 entries, 0 to 19118
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   customer_id            19119 non-null  int64
#  1   days_since_last_order  19119 non-null  int64
#  2   order_count            19119 non-null  int64
#  3   revenue                19119 non-null  int64
#  4   recency_score          19119 non-null  int64
#  5   frequency_score        19119 non-null  int64
#  6   revenue_score          19119 non-null  int64
#  7   total_score            19119 non-null  int64
#  8   customer_label         19119 non-null  str
# dtypes: int64(8), str(1)
# memory usage: 1.3 MB
#    customer_id  days_since_last_order  order_count  revenue  recency_score  \
# 0        29715                     62           12   853849              5
# 1        29722                     62           12   841909              5
# ...

# %%
rfm_segmentation.to_csv(r"C:\Users\chase\OneDrive\Desktop\Adventure Works Project\Clean csvs\rfm_segmentation_cleaned.csv", index = False)
