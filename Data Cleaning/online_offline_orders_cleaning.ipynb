# %% [markdown]
# Cleaning online vs. offline orders

# %%
import pandas as pd

online_offline_orders = pd.read_csv(r"C:\Users\chase\OneDrive\Desktop\Adventure Works Project\Raw csvs\online_offline_orders.csv")
online_offline_orders.info()
online_offline_orders.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_quarter   13 non-null     str
#  1   online_orders   13 non-null     int64
#  2   offline_orders  13 non-null     int64
# dtypes: int64(2), str(1)
# memory usage: 444.0 bytes
#   order_quarter  online_orders  offline_orders
# 0    2022-04-01            151             113
# 1    2022-07-01            464             190
# 2    2022-10-01            592             182
# 3    2023-01-01            588             186
# 4    2023-04-01            673             279

# %% [markdown]
# Must change "order_quarter" from str to datetime for Tableau. Will keep this as wide format since there are only two categories.

# %%
online_offline_orders["order_quarter"] = pd.to_datetime(online_offline_orders["order_quarter"])
online_offline_orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_quarter   13 non-null     datetime64[us]
#  1   online_orders   13 non-null     int64
#  2   offline_orders  13 non-null     int64
# dtypes: datetime64[us](1), int64(2)
# memory usage: 444.0 bytes

# %%
online_offline_orders.to_csv(r"C:\Users\chase\OneDrive\Desktop\Adventure Works Project\Clean csvs\online_offline_orders_cleaned.csv", index=False)
